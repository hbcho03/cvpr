# %%
# !git clone https://github.com/KaiyangZhou/CoOp.git
# Out:
# Cloning into 'CoOp'...
# remote: Enumerating objects: 455, done.
# remote: Counting objects: 100% (455/455), done.
# remote: Compressing objects: 100% (161/161), done.
# remote: Total 455 (delta 267), reused 416 (delta 250), pack-reused 0 (from 0)
# Receiving objects: 100% (455/455), 1.40 MiB | 5.45 MiB/s, done.
# Resolving deltas: 100% (267/267), done.

# %%
pwd
# Out:
# '/home/hbcho991/DAMP'

# %%
cd /home/hbcho991/DAMP/CoOp/
# Out:
# /home/hbcho991/DAMP/CoOp

# %%
# !bash scripts/cocoop/base2new_train.sh imagenet 1
# Out:
# 2024-08-31 17:36:13.924092: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-31 17:36:13.939267: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-31 17:36:13.956542: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-31 17:36:13.961591: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !bash scripts/cocoop/base2new_test.sh imagenet 1
# Out:
# 2024-08-31 18:11:57.734678: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-31 18:11:57.745370: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-31 18:11:57.756853: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-31 18:11:57.760190: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
